# %%
import pandas as pd
import numpy as np

url = 'https://www.ncei.noaa.gov/data/international-best-track-archive-for-climate-stewardship-ibtracs/v04r00/access/csv/ibtracs.ALL.list.v04r00.csv'
df = pd.read_csv(url, parse_dates=['ISO_TIME'], usecols=range(12),
                 skiprows=[1], na_values=[' ', 'NOT_NAMED'],
                 keep_default_na=False, dtype={'NAME': str})
df.head()
# Out:
#              SID  SEASON  NUMBER BASIN SUBBASIN NAME            ISO_TIME  \
# 0  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 03:00:00
# 1  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 06:00:00
# 2  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 09:00:00
# 3  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 12:00:00
# 4  1842298N11080    1842       1    NI       BB  NaN 1842-10-25 15:00:00
#
#   NATURE      LAT      LON  WMO_WIND  WMO_PRES
# 0     NR  10.9000  80.3000       NaN       NaN
# 1     NR  10.8709  79.8265       NaN       NaN
# 2     NR  10.8431  79.3524       NaN       NaN
# 3     NR  10.8188  78.8772       NaN       NaN
# 4     NR  10.8000  78.4000       NaN       NaN

# %%
print('Number of rows: '+str(df.shape[0]))

print('Number of North Atlantic Hurricane: '+str(sum(df.BASIN=='NA')))
# Out:
# Number of rows: 716354
# Number of North Atlantic Hurricane: 126593

# %% [markdown]
# ### 1) Get the unique values of the BASIN, SUBBASIN, and NATURE columns

# %%
print('Unique Values in Basin:' + str(df.BASIN.unique()))
print('Unique Values in Subbasin:' + str(df.SUBBASIN.unique()))
print('Unique Values in Nature:' + str(df.NATURE.unique()))
# Out:
# Unique Values in Basin:['NI' 'SI' 'NA' 'EP' 'WP' 'SP' 'SA']
# Unique Values in Subbasin:['BB' 'AS' 'MM' 'GM' 'NA' 'CS' 'WA' 'EA' 'CP']
# Unique Values in Nature:['NR' 'TS' 'ET' 'SS' 'MX' 'DS']

# %% [markdown]
# ### Rename the WMO_WIND and WMO_PRES columns to WIND and PRES

# %%
df=df.rename(columns={'WMO_WIND':'WIND','WMO_PRES':'PRES'})

# %% [markdown]
# ### 3) Get the 10 largest rows in the dataset by WIND

# %%
df.nlargest(10,'WIND')
# Out:
#                   SID  SEASON  NUMBER BASIN SUBBASIN      NAME  \
# 666142  2015293N13266    2015      96    EP       MM  PATRICIA
# 666140  2015293N13266    2015      96    EP       MM  PATRICIA
# 666144  2015293N13266    2015      96    EP       MM  PATRICIA
# 427655  1980214N11330    1980      57    NA       GM     ALLEN
# 178210  1935241N23291    1935      46    NA       NA       NaN
# 178211  1935241N23291    1935      46    NA       NA       NaN
# 178213  1935241N23291    1935      46    NA       GM       NaN
# 482093  1988253N12306    1988      74    NA       CS   GILBERT
# 552477  1997253N12255    1997      81    EP       MM     LINDA
# 605764  2005289N18282    2005      97    NA       CS     WILMA
#
#                   ISO_TIME NATURE   LAT    LON   WIND   PRES
# 666142 2015-10-23 12:00:00     TS  17.3 -105.6  185.0  872.0
# 666140 2015-10-23 06:00:00     TS  16.5 -105.4  180.0  886.0
# 666144 2015-10-23 18:00:00     TS  18.3 -105.3  180.0  878.0
# 427655 1980-08-07 18:00:00     TS  21.8  -86.4  165.0  899.0
# 178210 1935-09-03 00:00:00     TS  24.6  -80.5  160.0  892.0
# 178211 1935-09-03 02:00:00     TS  24.8  -80.8  160.0  892.0
# 178213 1935-09-03 06:00:00     TS  25.1  -81.1  160.0    NaN
# 482093 1988-09-14 00:00:00     TS  19.7  -83.8  160.0  888.0
# 552477 1997-09-12 06:00:00     TS  17.1 -109.6  160.0  902.0
# 605764 2005-10-19 12:00:00     TS  17.3  -82.8  160.0  882.0

# %% [markdown]
# ### Group the data on SID and get the 10 largest hurricanes by WIND

# %%
rmnan=df[df['WIND'].notna()]
rmnansid=rmnan.groupby('SID').max()
rmnansid.nlargest(10,'WIND')
# Out:
#                SEASON  NUMBER BASIN SUBBASIN      NAME            ISO_TIME  \
# SID
# 2015293N13266    2015      96    EP       MM  PATRICIA 2015-10-24 12:00:00
# 1980214N11330    1980      57    NA       NA     ALLEN 1980-08-11 18:00:00
# 1935241N23291    1935      46    NA       NA       NaN 1935-09-10 12:00:00
# 1988253N12306    1988      74    NA       NA   GILBERT 1988-09-20 00:00:00
# 1997253N12255    1997      81    EP       MM     LINDA 1997-09-17 18:00:00
# 2005289N18282    2005      97    NA       NA     WILMA 2005-10-26 18:00:00
# 2019236N10314    2019      52    NA       NA    DORIAN 2019-09-09 00:00:00
# 1998295N12284    1998      89    NA       NA     MITCH 1998-11-09 18:00:00
# 2005261N21290    2005      80    NA       NA      RITA 2005-09-26 06:00:00
# 2009288N07267    2009      82    EP       MM      RICK 2009-10-21 20:00:00
#
#               NATURE   LAT    LON   WIND    PRES
# SID
# 2015293N13266     TS  23.2  -94.0  185.0  1007.0
# 1980214N11330     TS  28.9  -30.0  165.0  1010.0
# 1935241N23291     TS  57.0  -31.2  160.0   996.0
# 1988253N12306     TS  43.4  -54.0  160.0  1008.0
# 1997253N12255     TS  23.5 -104.7  160.0  1007.0
# 2005289N18282     TS  45.5  -52.0  160.0  1004.0
# 2019236N10314     TS  51.6  -46.4  160.0  1011.0
# 1998295N12284     TS  63.5   -5.0  155.0  1005.0
# 2005261N21290     TS  39.5  -69.9  155.0  1009.0
# 2009288N07267     TS  24.3  -96.6  155.0  1005.0

# %% [markdown]
# ### Make a bar chart of the wind speed of the 20 strongest-wind hurricanes

# %%
largest20=rmnansid.nlargest(20,'WIND')
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.bar(x=range(len(largest20)),height=largest20.WIND)
plt.xticks(range(len(largest20)),largest20.NAME)
# Out:
# ([<matplotlib.axis.XTick at 0x7fe09fa6bed0>,
#   <matplotlib.axis.XTick at 0x7fe09fa79310>,
#   <matplotlib.axis.XTick at 0x7fe09fa78910>,
#   <matplotlib.axis.XTick at 0x7fe09f8e8410>,
#   <matplotlib.axis.XTick at 0x7fe09f8ea690>,
#   <matplotlib.axis.XTick at 0x7fe09f8f4bd0>,
#   <matplotlib.axis.XTick at 0x7fe09f8f6f10>,
#   <matplotlib.axis.XTick at 0x7fe09f9010d0>,
#   <matplotlib.axis.XTick at 0x7fe09f8f4150>,
#   <matplotlib.axis.XTick at 0x7fe09f903f90>,
#   <matplotlib.axis.XTick at 0x7fe09f906290>,
#   <matplotlib.axis.XTick at 0x7fe09f90c5d0>,
#   <matplotlib.axis.XTick at 0x7fe09f90e890>,
#   <matplotlib.axis.XTick at 0x7fe09f906d10>,
#   <matplotlib.axis.XTick at 0x7fe09f910e50>,
#   <matplotlib.axis.XTick at 0x7fe09f913110>,
#   <matplotlib.axis.XTick at 0x7fe09f915450>,
#   <matplotlib.axis.XTick at 0x7fe09f917790>,
#   <matplotlib.axis.XTick at 0x7fe09f925a50>,
#   <matplotlib.axis.XTick at 0x7fe09f926110>],
#  [Text(0, 0, 'PATRICIA'),
#   Text(1, 0, 'ALLEN'),
#   Text(2, 0, 'nan'),
#   Text(3, 0, 'GILBERT'),
#   Text(4, 0, 'LINDA'),
#   Text(5, 0, 'WILMA'),
#   Text(6, 0, 'DORIAN'),
#   Text(7, 0, 'MITCH'),
#   Text(8, 0, 'RITA'),
#   Text(9, 0, 'RICK'),
#   Text(10, 0, 'IRMA'),
#   Text(11, 0, 'nan'),
#   Text(12, 0, 'JANET'),
#   Text(13, 0, 'PATSY'),
#   Text(14, 0, 'CAMILLE'),
#   Text(15, 0, 'ANITA'),
#   Text(16, 0, 'DAVID'),
#   Text(17, 0, 'ANDREW'),
#   Text(18, 0, 'JOHN'),
#   Text(19, 0, 'KATRINA')])

# %% [markdown]
# ### Plot the count of all datapoints by Basin as a bar chart

# %%
rmnanbasin=rmnan.groupby('BASIN').count()
rmnanbasin['NUMBER'].plot(kind='bar')
# Out:
# <Axes: xlabel='BASIN'>

# %% [markdown]
# ### Plot the count of unique hurricanes by Basin as a bar chart.

# %%
rmnansidmaxcount=rmnan.groupby('SID').max().groupby('BASIN').count()
rmnansidmaxcount
rmnansidmaxcount['NUMBER'].plot(kind='bar')
# Out:
# <Axes: xlabel='BASIN'>

# %% [markdown]
# ### Make a hexbin of the location of datapoints in Latitude and Longitude

# %%
plt.hexbin(y=rmnansid['LAT'], x=rmnansid['LON'],cmap='Blues',gridsize=25)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar()

# %% [markdown]
# ### 9) Find Hurricane Katrina (from 2005) and plot its track as a scatter plot

# %%
katrina=rmnan[rmnan['NAME']=='KATRINA']
katrina05=katrina[katrina['SEASON']==2005]
s1=plt.scatter(x=katrina05['LON'],y=katrina05['LAT'],c=katrina05['WIND'],cmap='viridis')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(s1)

# %% [markdown]
# ### 10) Make time the index on your dataframe

# %%
timeidx=rmnan.set_index('ISO_TIME')

timeidx
# Out:
#                                SID  SEASON  NUMBER BASIN SUBBASIN    NAME  \
# ISO_TIME
# 1851-06-25 00:00:00  1851175N26270    1851       5    NA       GM     NaN
# 1851-06-25 06:00:00  1851175N26270    1851       5    NA       GM     NaN
# 1851-06-25 12:00:00  1851175N26270    1851       5    NA       GM     NaN
# 1851-06-25 18:00:00  1851175N26270    1851       5    NA       GM     NaN
# 1851-06-25 21:00:00  1851175N26270    1851       5    NA       GM     NaN
# ...                            ...     ...     ...   ...      ...     ...
# 2022-11-10 19:00:00  2022311N21293    2022      46    NA       GM  NICOLE
# 2022-11-11 00:00:00  2022311N21293    2022      46    NA       GM  NICOLE
# 2022-11-11 06:00:00  2022311N21293    2022      46    NA       NA  NICOLE
# 2022-11-11 12:00:00  2022311N21293    2022      46    NA       NA  NICOLE
# 2022-11-11 18:00:00  2022311N21293    2022      46    NA       NA  NICOLE
#
#                     NATURE      LAT      LON  WIND    PRES
# ISO_TIME
# 1851-06-25 00:00:00     TS  27.5333 -94.2667  80.0     NaN
# 1851-06-25 06:00:00     TS  27.8000 -95.0800  80.0     NaN
# 1851-06-25 12:00:00     TS  27.9000 -95.7333  80.0     NaN
# 1851-06-25 18:00:00     TS  28.0333 -96.2667  80.0     NaN
# 1851-06-25 21:00:00     TS  28.1333 -96.5667  80.0     NaN
# ...                    ...      ...      ...   ...     ...
# 2022-11-10 19:00:00     TS  29.2000 -83.0000  40.0   989.0
# 2022-11-11 00:00:00     TS  30.1000 -84.0000  35.0   992.0
# 2022-11-11 06:00:00     TS  31.2000 -84.6000  30.0   996.0
# 2022-11-11 12:00:00     TS  33.2000 -84.6000  25.0   999.0
# 2022-11-11 18:00:00     DS  35.4000 -83.8000  25.0  1000.0
#
# [157570 rows x 11 columns]

# %% [markdown]
# ### 11) Plot the count of all datapoints per year as a timeseries

# %%
yearidx=timeidx.resample('YE').count()
yearidx['NUMBER'].plot()
plt.xlabel('Year')
plt.ylabel('Number of Datapoints')
# Out:
# Text(0, 0.5, 'Number of Datapoints')

# %% [markdown]
# ### 12) Plot all tracks from the North Atlantic in 2005

# %%
basinsort=timeidx.groupby('BASIN')
NAbasin=basinsort.get_group('NA')
NAbasin05=NAbasin.groupby('SEASON')
NAbasin05=NAbasin05.get_group(2005)
NAbasinSID=NAbasin05.groupby('NAME')

plt.subplots(figsize=(12,12))
for grpidx, grp in NAbasinSID:
    plt.plot(grp['LON'],grp['LAT'],label=grpidx)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Tracks in the North Atlantic (2005)')
plt.legend()

# %% [markdown]
# ### Create a filtered dataframe that contains only data since 1970 from the North Atlantic (“NA”) Basin

# %%
NAbasinfilter=NAbasin[NAbasin['SEASON']>=1970]
NAbasinfilter
# Out:
#                                SID  SEASON  NUMBER BASIN SUBBASIN    NAME  \
# ISO_TIME
# 1970-05-17 18:00:00  1970138N12281    1970      43    NA       CS    ALMA
# 1970-05-18 00:00:00  1970138N12281    1970      43    NA       CS    ALMA
# 1970-05-18 06:00:00  1970138N12281    1970      43    NA       CS    ALMA
# 1970-05-18 12:00:00  1970138N12281    1970      43    NA       CS    ALMA
# 1970-05-18 18:00:00  1970138N12281    1970      43    NA       CS    ALMA
# ...                            ...     ...     ...   ...      ...     ...
# 2022-11-10 19:00:00  2022311N21293    2022      46    NA       GM  NICOLE
# 2022-11-11 00:00:00  2022311N21293    2022      46    NA       GM  NICOLE
# 2022-11-11 06:00:00  2022311N21293    2022      46    NA       NA  NICOLE
# 2022-11-11 12:00:00  2022311N21293    2022      46    NA       NA  NICOLE
# 2022-11-11 18:00:00  2022311N21293    2022      46    NA       NA  NICOLE
#
#                     NATURE   LAT   LON  WIND    PRES
# ISO_TIME
# 1970-05-17 18:00:00     TS  11.5 -79.0  25.0     NaN
# 1970-05-18 00:00:00     TS  11.8 -79.3  25.0     NaN
# 1970-05-18 06:00:00     TS  12.1 -79.7  25.0     NaN
# 1970-05-18 12:00:00     TS  12.3 -80.1  25.0     NaN
# 1970-05-18 18:00:00     TS  12.6 -80.5  25.0     NaN
# ...                    ...   ...   ...   ...     ...
# 2022-11-10 19:00:00     TS  29.2 -83.0  40.0   989.0
# 2022-11-11 00:00:00     TS  30.1 -84.0  35.0   992.0
# 2022-11-11 06:00:00     TS  31.2 -84.6  30.0   996.0
# 2022-11-11 12:00:00     TS  33.2 -84.6  25.0   999.0
# 2022-11-11 18:00:00     DS  35.4 -83.8  25.0  1000.0
#
# [23998 rows x 11 columns]

# %% [markdown]
# ### Plot the number of datapoints per day from this filtered dataframe

# %%
NAbasinfiltertime=NAbasinfilter.resample('D').count()
plt.subplots(figsize=(12,4))
plt.bar(NAbasinfiltertime.index,NAbasinfiltertime['SEASON'])
plt.xlabel('Date')
plt.ylabel('Number of Datapoints')
# Out:
# Text(0, 0.5, 'Number of Datapoints')

# %% [markdown]
# ### Calculate the climatology of datapoint counts as a function of dayofyear
# Plot the mean and standard deviation on a single figure
#
#
# NOTE: Assuming PRES is Pressure.

# %%
#The difference in y-axis value is because I removed NaN in my dataset.
NAbasinfiltertime['Date']=pd.to_datetime(NAbasinfiltertime.index).date
NAbasinfiltertime['DOY'] = pd.to_datetime(NAbasinfiltertime['Date']).dt.dayofyear

calc=NAbasinfiltertime.groupby('DOY').agg({'WIND':['mean','std']})
fig,(ax1)=plt.subplots(1,1,figsize=(10,10),sharex=True)
ax1.plot(calc.index,calc['WIND']['mean'],label='Mean')
ax1.plot(calc.index,calc['WIND']['std'],label='Standard Deviation')
ax1.legend()

# %%
## My alternative interpretation of the question.

NAbasinfilter['Date']=pd.to_datetime(NAbasinfilter.index).date
NAbasinfilter['DOY'] = pd.to_datetime(NAbasinfilter['Date']).dt.dayofyear
fig,(ax1,ax2)=plt.subplots(2,1,figsize=(10,10),sharex=True)
calc=NAbasinfilter.groupby('DOY').agg({'WIND':[np.mean,np.std],'PRES':[np.mean,np.std]})

ax1.plot(calc.index,calc['WIND']['mean'],label='Mean')
ax1.fill_between(calc.index,calc['WIND']['mean']+calc['WIND']['std'],calc['WIND']['mean']-calc['WIND']['std'], color='black', alpha=.2,label='Standard Deviation')
ax1.legend()

ax1.set_ylabel('Wind')
ax2.set_xlabel('Day of Year')

ax2.plot(calc.index,calc['PRES']['mean'],label='Mean')
ax2.fill_between(calc.index,calc['PRES']['mean']+calc['PRES']['std'],calc['PRES']['mean']-calc['PRES']['std'], color='black', alpha=.2,label='Standard Deviation')

ax2.set_ylabel('Pressure')
# Out:
# /tmp/ipykernel_720743/2556831808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NAbasinfilter['Date']=pd.to_datetime(NAbasinfilter.index).date
# /tmp/ipykernel_720743/2556831808.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NAbasinfilter['DOY'] = pd.to_datetime(NAbasinfilter['Date']).dt.dayofyear
# /tmp/ipykernel_720743/2556831808.py:4: FutureWarning: The provided callable <function mean at 0x7fe1f40853a0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   calc=NAbasinfilter.groupby('DOY').agg({'WIND':[np.mean,np.std],'PRES':[np.mean,np.std]})
# /tmp/ipykernel_720743/2556831808.py:4: FutureWarning: The provided callable <function std at 0x7fe1f40854e0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   calc=NAbasinfilter.groupby('DOY').agg({'WIND':[np.mean,np.std],'PRES':[np.mean,np.std]})
# Text(0, 0.5, 'Pressure')

# %% [markdown]
# ### Use transform to calculate the anomaly of daily counts from the climatology
# Resample the anomaly timeseries at annual resolution and plot a line with dots as markers.
#
# Which years stand out as having anomalous hurricane activi
# y?

# %%
NAbasinfilter['Date']=pd.to_datetime(NAbasinfilter.index).date
NAbasinfilter['DOY'] = pd.to_datetime(NAbasinfilter['Date']).dt.dayofyear


def standardize(x):
    return (x - x.mean())/x.std()
    
wpbasin=NAbasinfilter[['DOY','WIND','PRES']]
wpbasin
p=wpbasin.groupby('DOY').transform(standardize)
q=p.resample('YE').mean()
q.plot(y=['PRES','WIND'],marker='o')


print(q.index[((q['WIND'] > 0.2) | (q['WIND'] < -0.2))&((q['PRES'] > 0.2) | (q['PRES'] < -0.2))].year)

### These are the anomalous years when both wind and pres is above 0.2 or below -0.2.
# Out:
# /tmp/ipykernel_720743/3555881983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NAbasinfilter['Date']=pd.to_datetime(NAbasinfilter.index).date
# /tmp/ipykernel_720743/3555881983.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NAbasinfilter['DOY'] = pd.to_datetime(NAbasinfilter['Date']).dt.dayofyear
# Index([1970, 1977, 1978, 1980, 1983, 1987, 1991, 1994, 1995, 1996, 1998, 1999,
#        2002, 2004, 2005, 2013, 2017],
#       dtype='int32', name='ISO_TIME')
